# %%
print('hello')
# Out:
# hello

# %%
print(155/15)
print(type(155/15))
# Out:
# 10.333333333333334
# <class 'float'>

# %%
print(type(163.7/18))
# Out:
# <class 'float'>

# %%
print(type(178.8/10.2))
# Out:
# <class 'float'>

# %%
a = -3.3
b = -2
print(a/b)
print(type(a/b))
# Out:
# 1.65
# <class 'float'>

# %%
a = 10 
print(a)
# Out:
# 10

# %%
if(360 > 0):
   if( 360 % 2 == 0):
      if( 360 / 10 == 0):
         if( 360 > 300):
            print("is positive , is even , is divisible by 1o , is greater than 300")

# %%
number = int(input("Enter a number : "))
if(number>0):
    print(number,"is positive")
elif( number == 0):
    print(number,"is zero")
else:
    print(number,"is negative")
