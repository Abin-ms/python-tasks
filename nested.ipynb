# %%
if(360 > 0):
   if( 360 % 2 == 0):
      if( 360 / 10 == 0):
         if( 360 > 300):
            print("is positive , is even , is divisible by 1o , is greater than 300")

# %%
if(360 > 0):
   print("ahha")
   if( 360 % 2 == 0):
      print("kjaa")
      if( 360 % 10 == 0):
         print("jjaja")
         if( 360 > 300):
            print("is positive , is even , is divisible by 1o , is greater than 300")

# %%
if(144 > 0):
    print("144 is positive")
    if(144 % 2 == 0):
        print("144 is even")
        if( 144 % 4 == 0):
           print("144 is divisible by 4")
        elif( 144 % 8 == 0 ):
            print("144 is divisible by 8")
        elif( 144 % 12 ==0 ):
            print("144 is divisible by 12")
        else:
            print("conditions not satisfied")
# Out:
# 144 is positive
# 144 is even
# 144 is divisible by 4

# %%
if( 225 > 0):
    print("225 is positive")
    if( 225 % 2 != 0):
        print("225 is odd")
        if( 225 % 3 == 0):
            print("225 is divisible by 3")
            if( 225 % 5 == 0):
                print("225 is divisible by 5")
                if( 255 % 15 == 0):
                    print("255 is divisible by 15")
else:
    print("conditions are not satisfied")
# Out:
# 225 is positive
# 225 is odd
# 225 is divisible by 3
# 225 is divisible by 5
# 255 is divisible by 15

# %%
if( 120 > 0 ):
    print("120 is positive")
    if( 120 % 2 == 0):
        print("120 is even")
        if( 100 > 120):
            print("120 is below 100")
        # else:
        #     print("120 is avove 100")
        elif( (100 < 120) and (120 < 150)):
            print("it is between 100 and 150")
        elif( 120 > 150 ):
            print("120 is above 150")
        else:
            print("conditions are not satisfied")
# Out:
# 120 is positive
# 120 is even
# it is between 100 and 150

# %%
if( 99 > 0):
    print("99 is positive")
    if( 99 % 2 != 0):
        print("99 is odd")
        if( 99 % 3 == 0):
            print(" 99 is divisible by 3")
            if( 99 % 9 == 0):
                print("99 is divided by 9")
    else:
        print("99 is even")
# Out:
# 99 is positive
# 99 is odd
#  99 is divisible by 3
# 99 is divided by 9

# %%
if( 180 > 100):
    print("180 is greater than 100")
    if( 180 % 2 == 0):
        print("180 is even")
        if( 180 % 10 == 0 ):
            print("180 is divisible by 10")
            if( 180 > 150):
                print("180 is greater than 150")
            else:
                print("180 is smaller than 150")  
        else:
            print("180 is not divisible by 10")
    else:
        print("180 is odd")
    

else:
    print("180 is smaller than 100")
# Out:
# 180 is greater than 100
# 180 is even
# 180 is divisible by 10
# 180 is greater than 150

# %%
if( 72 > 0):
    print("72 is positive")
    if( 72 % 2 ==0 ):
        print("72 is even")
        if( 72 % 4 == 0):
            print("72 is divided by 4")
        elif( 72 % 6 == 0):
            print("72 is divisible by 6")
        elif( 72 % 8 == 0 ):
            print("72 is divisible by 8") 
    else:
        print("72 is odd")

else:
    print("72 is negative")
# Out:
# 72 is positive
# 72 is even
# 72 is divided by 4

# %%
if( 125 > 0 ):
    print("125 is positive")
    if( 125 % 2 != 0):
        print("125 is odd")
        if( 125 % 5 == 0):
            print("125 is divisible by 5")
            if( 125 > 100):
                print("125 is greater than 100")
        else:
            print("125 is not divisible by 5")
    else:
        print("125 is even")
else:
    print("125 is negative")
# Out:
# 125 is positive
# 125 is odd
# 125 is divisible by 5
# 125 is greater than 100

# %%
if( 96 > 0):
    print("96 is positive")
    if( 96 % 2 == 0):
        print("96 is even")
        if(( 96 % 4 == 0) and ( 96 % 8 == 0)):
            print("96 is divisible by 4 and 8")
            if( 96 > 90):
                print("96 is greater than 90")
# Out:
# 96 is positive
# 96 is even
# 96 is divisible by 4 and 8
# 96 is greater than 90

# %%
if( 150 > 0):
    print("150 is positive")
    if( 150 % 2 == 0 ):
        print("150 is even")
        if( 150 % 5 == 0):
            print("150 is divisible by 5")
            if( 100 > 150):
                print("150 is below 100")
            elif( (100<150) and (150 < 200)):
                print("150 is between 150 and 200")
            elif( 150 > 200):
                print(" 150 is above 200")
# Out:
# 150 is positive
# 150 is even
# 150 is divisible by 5
# 150 is between 150 and 200

# %%
if( 216 > 100):
    print("216 is greater than 100")
    if( 216 % 2 == 0)

# %%
# 17

if( 225 > 100):
    print("255 is greater than 100")
    if( 225 % 2 != 0 ):
        print("225 is odd")
        if( 225 % 3 == 0):
            print("255 is divisible by 3")
            if( 255 % 5 == 0):
                print("225 is divisible by 5")
                if( 255 > 200):
                    print("255 is greater than 200")
else:
    print("255 is smaller than 100")
# Out:
# 255 is greater than 100
# 225 is odd
# 255 is divisible by 3
# 225 is divisible by 5
# 255 is greater than 200
