# %%
# question11
if(36%6==0):
    print("36 is divisible by 6")
# Out:
# 36 is divisible by 6

# %%
# question12

if(37 % 5 != 0):
    print("37 is not divisible by 5")
# Out:
# 37 is not divisible by 5

# %%
if(48 % 8 == 0):
    print("48 is a multiple of 8")
# Out:
# 48 is a multiple of 8

# %%
if(50 % 7 != 0):
    print("50 is not a multiple of 7")
# Out:
# 50 is not a multiple of 7

# %%
if((25>10) & (25<40)):
    print("25 is between 10 amd 40")
# Out:
# 25 is between 10 amd 40

# %%
a = 25 
b = 10
c = 40
if((a>b) & (a<40)):
    print("25 is between 10 and 40")
# Out:
# 25 is between 10 and 40

# %%
a = 55
if((a>20) & (a<45)):
    print("55 is between 20 and 45")
else:
    print("55 is not in the range of 20 amd 45")
# Out:
# 55 is not in the range of 20 amd 45

# %%
a = 80
if((a > 35) & (a>60)):
    print("80 is greater than 35 and 60")
# Out:
# 80 is greater than 35 and 60

# %%
a = 12
if((a<20) & (a<30)):
    print("12 is less than 20 and 30")
# Out:
# 12 is less than 20 and 30

# %%
a = 15
if((a == 15) | (a == 25)):
    print("15 is either equal to 15 or 25")
# Out:
# 15 is either equal to 15 or 25

# %%
a = 20
if((a != 10) & (a != 30)):
    print("20 is different from both 10 and 30")
# Out:
# 20 is different from both 10 and 30

# %%
a = 8+14;
if(a>0):
    print("8 + 14 is positive")
# Out:
# 8 + 14 is positive

# %%
a = 11 + 13;
if(a % 2 == 0):
    print("sum of 11 and 13 is even")
# Out:
# sum of 11 and 13 is even

# %%
a = 42 + 7;
if(a % 7 == 0):
    print("42 is divisible by 7")
# Out:
# 42 is divisible by 7

# %%
a = 25 - 10;
if(a > 0):
    print("the difference between 25 and 10 is positive")
# Out:
# the difference between 25 and 10 is positive

# %%
a = 18 - 6;
if(a % 2 == 0):
    print("the difference between 18 and 6 id even")
# Out:
# the difference between 18 and 6 id even

# %%
a = 7
b = 9
if((7*9) > 0):
    print("The product of 7 and 9 is positive")
# Out:
# The product of 7 and 9 is positive

# %%
a = 12
b = -5
if((a*b) < 0):
    print("The product of 12 and and -5 ")
# Out:
# The product of 12 and and -5

# %%
a = 36 
b = 6
if((a*b) % 6 == 0):
    print("the product of 36 and 6 is divisible by 6")
# Out:
# the product of 36 and 6 is divisible by 6

# %%
a = 45
if(a > 9):
    print("45 is a two digit number")
# Out:
# 45 is a two digit number

# %%
a = 125
if(a > 99):
    print("125 is a three digit number")
# Out:
# 125 is a three digit number

# %%
a = 150
if(a > 100):
    print("150 is greater than 100")
# Out:
# 150 is greater than 100

# %%
a = 75
if(a<100):
    print("75 is smaller than 100")
# Out:
# 75 is smaller than 100

# %%
a = 600
if(a > 500):
    print("600 is greater than 500")
# Out:
# 600 is greater than 500

# %%
a = 250
if(a < 500):
    print("250 is smaller than 500")
# Out:
# 250 is smaller than 500

# %%
a = 72
if(( a % 8 == 0) and ( a % 9 == 0)):
    print("72 is divisible by both 8 and 9")
# Out:
# 72 is divisible by both 8 and 9

# %%
a = 35
if(( a % 6 == 0) or ( a % 7 == 0)):
    print("35 is divisible by either 6 or 7")
# Out:
# 35 is divisible by either 6 or 7

# %%
a = 25
if((a > 10) and (a < 40)):
    print("25 is greater than 10 and less than 40")
# Out:
# 25 is greater than 10 and less than 40

# %%
a = 15 
if((a<30) and (a>5)):
    print("15 is less than 30 and greater than 5")
# Out:
# 15 is less than 30 and greater than 5

# %%
a = 12 
b = 18
if((a % 2 == 0) and ( b % 2 == 0)):
    print("12 and 18 have the same parity")
# Out:
# 12 and 18 have the same parity

# %%
a = 21 
b = 9
if((a % 2 != 0) and ( b % 2 != 0)):
    print("21 and 9 are of different parity")
# Out:
# 21 and 9 are of different parity

# %%
a = 18
if((18/2 == 9)):
    print("18 is exactly the twice of 9")
# Out:
# 18 is exactly the twice of 9

# %%
a = 24
if(24 / 8 == 3):
    print("24 is exactly three times of 8")
# Out:
# 24 is exactly three times of 8

# %%
a = 16
if( (a / 2 == 8)):
    print("8 is the half of 16")
# Out:
# 8 is the half of 16

# %%
a = 7
if(( a * a) == 49):
    print("49 is the square of 7")
# Out:
# 49 is the square of 7

# %%
a = 20 + 30
if( a < 60):
    print("60 is greater than the sum of 30 and 20")
# Out:
# 60 is greater than the sum of 30 and 20

# %%
a = 20 + 5
if( a > 10):
    print("The sum of 20 and 5 is greater than 10")
# Out:
# The sum of 20 and 5 is greater than 10

# %%
a = 120 - 20
if( a == 100):
    print("100 is equal to 120 - 20.")
# Out:
# 100 is equal to 120 - 20.
