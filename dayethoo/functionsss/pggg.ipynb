# %%
# crate a function sum pass 2 arguments and execute it

def sum(a,b):
    a = a + b
    print("sum is : ",a)
sum(10,2)
# Out:
# sum is :  12

# %%
# create a function called "details" pass the name of the student , mark and grade .

def details(name , mark , grade):
    print("Name : ",name)
    print("mark : ",mark)
    print("Grade : ",grade)

details("Abin" , 82 , "A")
# Out:
# Name :  Abin
# mark :  82
# Grade :  A

# %%
# create a function called sum , pass three values but recieve only two.

def sum(a , b , c):
    print(a)
    print(b)

sum(10 , 20 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       4     print(a)
#       5     print(b)
# ----> 7 sum(10 , 20 )
#
# TypeError: sum() missing 1 required positional argument: 'c'

# %%
def sum(a , b , c = 50 ):
    d = a + b + c
    print(d)

sum(40,20,10)
# Out:
# 70

# %%
def sum(a = 10 , b = 5):
    print( a + b)
sum()
# Out:
# 15

# %%
# create a fn() name details print name , class , mark .

def details( name = "Abin" , Class = "10 B" , mark = 82):
    print(name)
    print(Class)
    print(mark)

details()
# Out:
# Abin
# 10 B
# 82

# %%
# write the function called "power", let the default argument to be passed , pass the value to find resultant of this expression

def power(num = 20):
    print("Power : ",num ** 2)

power()
# Out:
# Power :  400

# %%
def power(num , a = 2):
    print(num ** a)
power(2)
# Out:
# 4

# %%
# Q1

def greet(name):
    print(name)
greet("Abin")
# Out:
# Abin

# %%
# Q1
def add(a , b):
    print(a + b)

add(4 , 5)
# Out:
# 9

# %%
# Q3
def student(name , age):
    print(name)
    print(age)

student("Abin" , 21)

# %%
# Q4
def square(a):
    print("Square",a*a)

square(10)
# Out:
# Square 100

# %%
# Q5
def multiply(a , b):
    print(a * b)

multiply( 3 ,2)
# Out:
# 6

# %%
# Q6

def greet(name = "Student"):
    print(name)

greet()

# %%
# Q7

def country(name = "India"):
    print(name)

country()
# Out:
# India

# %%
# Q8

def show_age( age = 18):
    print(age)

show_age()
# Out:
# 18

# %%
# Q9
def collage(collage_name = "ABC collage"):
    print(collage_name)

collage()
# Out:
# ABC collage

# %%
# 10
def power(number , power = 2):
    print("power = ", number ** power)

power(2)
# Out:
# power =  4

# %%
# SEP - 18

# %%
# 1
def student( name , age = 18):
    print("Name : ",name)
    print("Age : ",age)

student("Abin")
student("Abin",21)
# Out:
# Name :  Abin
# Age :  18
# Name :  Abin
# Age :  21

# %%
# 2
def bill(item , quantity = 1):
    print("item name : ",item)
    print("Quantity :",quantity)

bill("Mobile Phone")
bill("Laptop" , 2)
# Out:
# item name :  Mobile Phone
# Quantity : 1
# item name :  Laptop
# Quantity : 2

# %%
# 3
def welcome( name , message = "Welcome"):
    print(name)
    print(message)

welcome("Abin")
welcome("Abin" , "Welocmee!!")
# Out:
# Abin
# Welcome
# Abin
# Welocmee!!

# %%
# 4
def employee(name , department = "IT"):
    print("employee name :",name)
    print("Department : ",department)

employee("Rahul")
employee("Anu")
employee("HR")
# Out:
# employee name : Rahul
# Department :  IT
# employee name : Anu
# Department :  IT
# employee name : HR
# Department :  IT

# %%
# 5

def calculate( a , b = 10):
    print(a + b)

calculate(5)
# Out:
# 15

# %%
# set - 2 
# 1

def phone(brand , price):
    print("Brand name :",brand)
    print("Price :",price)

phone("Iphone",139000)
# Out:
# Brand name : Iphone
# Price : 139000

# %%
# 2
def movie( name , language = "English"):
    print("Movie name :",name)
    print("Language :",language)

movie("Inception")
# Out:
# Movie name : Inception
# Language : English

# %%
# 3
def book( title , author = "Unknown"):
    print("Book name :",title)
    print("Author namae :",author)
book("A walk to remember")
# Out:
# Book name : A walk to remember
# Author namae : Unknown

# %%
# 4
def login( username , password = "12345"):
    print("Login successfull!!!")

login("Abin")
login("Abin","123456")
# Out:
# Login successfull!!!
# Login successfull!!!

# %%
# 5
def collage( name , course = "BCA"):
    print("Collage name : ",name)
    print("Course :",course)

collage("MIT")
# Out:
# Collage name :  MIT
# Course : BCA

# %%
# 6
def travel( place , days = 2):
    print("Destination :",place)
    print("Number of days :",days)

travel("coorg")
# Out:
# Destination : coorg
# Number of days : 2

# %%
# 7
def order( item , quantity = 1):
    print(item+" is out for delivery!!")
    print("Quantity : ",quantity)

order("Skybags  Bagpack")
# Out:
# Skybags  Bagpack is out for delivery!!
# Quantity :  1

# %%
# 8
def exam( subject , marks = 100):
    print("Subject :",subject)
    print("Total marks :",marks)

exam("Maths")
# Out:
# Subject : Maths
# Total marks : 100

# %%
# 9
def account( name , balance = 0):
    print("Account holder's name : ",name)
    print("Available balance :",balance)

account("Abin")
# Out:
# Account holder's name :  Abin
# Available balance : 0

# %%
# 10
def game( name , players = 4):
    print("Game name: ",name)fr
    
    print("number of players : ",players)

game("BGMI")
# Out:
# Game name:  BGMI
# number of players :  4

# %%
# 11
